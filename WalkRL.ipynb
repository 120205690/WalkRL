# %%
# !pip install pybullet -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 11.6 MB/s eta 0:00:00

# %%
# !pip install wandb -q

# %%
# !python main.py
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:440: UserWarning: WARN: The `registry.env_specs` property along with `EnvSpecTree` is deprecated. Please use `registry` directly as a dictionary instead.
#   logger.warn(
# wandb: Currently logged in as: v10. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.6
# wandb: Run data is saved locally in /content/wandb/run-20240425_124513-wstnzue3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run worldly-dream-3
# wandb: ⭐️ View project at https://wandb.ai/v10/WalkRL%20humanoidbulletenv-v0
# wandb: 🚀 View run at https://wandb.ai/v10/WalkRL%20humanoidbulletenv-v0/runs/wstnzue3
# pybullet build time: Nov 28 2023 23:45:17
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# ...

# %%
# !python main.py

# %%
# !tar -xvzf /content/hw4data.tar.gz

# %%
 # %pip install -r /content/requirements.txt
